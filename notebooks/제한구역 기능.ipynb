# %%
import sys
sys.path.append("..")

import seavoyage as sv

sv.register_custom_restriction('hra', "./restrictions/hra.geojson")
sv.register_custom_restriction('jwc', "./restrictions/jwc.geojson")
# Out:
# [2025-04-29 11:53:36,781][INFO][restriction] 제한 구역 등록 성공: hra, 파일: ./restrictions/hra.geojson
# [2025-04-29 11:53:36,783][INFO][restriction] 제한 구역 등록 성공: jwc, 파일: ./restrictions/jwc.geojson

# %%
from seavoyage.exceptions import DestinationInRestrictionError


start_point1 = (132.0, 34.3)  
end_point1 = (57.0, 24.828) # 제한구역 내부의 도착점

def test_route(start_point, end_point):
    normal_route = sv.seavoyage(
        start_point, 
        end_point
    )

    restricted_route = sv.seavoyage(
        start_point, 
        end_point,
        restrictions=['jwc']
    )

    print("Normal route:", normal_route)
    print("Restricted route:", restricted_route)
    return normal_route, restricted_route

try:# 제한구역 내부 도착점 시 에러 발생 테스트트
    normal_route, restrict_route = test_route(start_point1, end_point1)
except DestinationInRestrictionError as e:
    print(e)
# Out:
# [2025-04-29 11:53:36,798][INFO][base] 출발점 (132.0, 34.3)와 목적지 (57.0, 24.828) 사이의 경로 계산 시작
# [2025-04-29 11:53:36,834][INFO][m_network] 시작 좌표: (132.0, 34.3), 목적지 좌표: (57.0, 24.828)
# [2025-04-29 11:53:36,835][INFO][m_network] 현재 적용된 기본 제한 구역: ['northwest']
# [2025-04-29 11:53:36,836][INFO][m_network] 현재 적용된 커스텀 제한 구역: []
# [2025-04-29 11:53:36,837][INFO][m_network] 출발점 (132.0, 34.3)에서 가장 가까운 네트워크 노드: (131.64671, 33.761284)
# [2025-04-29 11:53:36,838][INFO][m_network] 출발점 노드 (131.64671, 33.761284)의 이웃 노드 수: 3
# [2025-04-29 11:53:36,838][INFO][m_network] 출발점 노드 (131.64671, 33.761284)의 고립 여부 검사 시작
# [2025-04-29 11:53:36,838][INFO][m_network]   - 이웃 노드 (131.952, 33.609): 유효한 경로 = True
# [2025-04-29 11:53:37,083][INFO][m_network] 경로 탐색 성공: 52 노드
# [2025-04-29 11:53:37,085][INFO][base] 요청된 제한 구역: ['jwc']
# [2025-04-29 11:53:37,086][INFO][base] 커스텀 제한 구역 'jwc' 발견
# [2025-04-29 11:53:37,086][INFO][m_network] Restriction added: jwc
# [2025-04-29 11:53:37,087][INFO][base] 출발점 (132.0, 34.3)와 목적지 (57.0, 24.828) 사이의 경로 계산 시작
# [2025-04-29 11:53:37,089][ERROR][base] 도착점 ['57°00.000N', '24°49.680E']이 제한 구역 'jwc' 내에 있습니다
# [2025-04-29 11:53:37,090][ERROR][base] 경로 오류: 목적지 ['57°00.000N', '24°49.680E']가 제한 구역 'jwc' 내에 있습니다.
# 목적지 ['57°00.000N', '24°49.680E']가 제한 구역 'jwc' 내에 있습니다.

# %%
start_point2 = (35.73436, 25.45588)
end_point2 = (18.21397, 35.28498)

# 막혀있는 경로 테스트
def test_route(start_point, end_point):
    normal_route = sv.seavoyage(
        start_point, 
        end_point
    )

    restricted_route = sv.seavoyage(
        start_point, 
        end_point,
        restrictions=['jwc', 'suez']
    )

    print("Normal route:", normal_route)
    print("Restricted route:", restricted_route)
    return normal_route, restricted_route

test_route(start_point2, end_point2)
# Out:
# [2025-04-21 14:46:47,739][INFO][base] 요청된 제한 구역: ['jwc', 'suez']
# [2025-04-21 14:46:47,740][INFO][base] 커스텀 제한 구역 'jwc' 발견
# [2025-04-21 14:46:47,740][INFO][base] 기본 제한 구역 'suez' 발견
