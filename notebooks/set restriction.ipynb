# %%
import sys
sys.path.append("..")

import seavoyage as sv

sv.register_custom_restriction('hra', sv.get_restriction_path('hra.geojson'))
# Out:
# 제한 구역 등록 성공: hra, 파일: c:\Users\admin\Projects\4_piusdev\seavoyage\seavoyage\data\geojson\restrictions\hra.geojson
