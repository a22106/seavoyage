# %%
import sys
sys.path.append("..")
import seavoyage as sv

# %%
mnet = sv.get_m_network_100km()

# %%
mnet.add_edges_for_new_node_knn_delaunay((126.757257, 30.518242))
# Out:
# [2025-04-18 19:24:21,478][INFO][m_network] 신규 노드에 대해 KNN+Delaunay 엣지 생성 완료: 5개
# [((126.757257, 30.518242),
#   (np.float64(128.135), np.float64(31.385)),
#   162.94038792801825),
#  ((126.757257, 30.518242),
#   (np.float64(126.705), np.float64(32.59)),
#   230.42249349540128),
#  ((126.757257, 30.518242),
#   (np.float64(128.9), np.float64(31.4)),
#   226.619093908247),
#  ((126.757257, 30.518242),
#   (np.float64(124.89), np.float64(29.085)),
#   240.5330750112552),
#  ((126.757257, 30.518242),
#   (np.float64(127.22), np.float64(32.9275)),
#   271.44820237488176)]
