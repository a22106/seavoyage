# %%
import sys
sys.path.append("..")
import seavoyage as sv

sv.constants.UnitEnum.values_list()
sv.constants.AvoidPassageEnum.values_list()
# Out:
# ['babalmandab',
#  'bosporus',
#  'gibraltar',
#  'suez',
#  'panama',
#  'ormuz',
#  'northwest',
#  'malacca',
#  'sunda',
#  'chili',
#  'south_africa']
